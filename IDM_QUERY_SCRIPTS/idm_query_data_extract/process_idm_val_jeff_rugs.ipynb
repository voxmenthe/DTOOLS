# %%
import numpy as np
import dask.dataframe as dd
import pandas as pd
from mlt.default import selector as s
import cv2, os
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Configs

# %%
ATTR_DATA_FILE = "raw_attribute_data_shrek_cleaned.h5"
IMAGE_DATA_FILE = "raw_image_data_patrick.h5"



# Please choose limited CATEGORIES. This will avoid Memory issues.
SELECTED_CATEGORIES = ['BOOT', 'BOOTS', "PUMP", "PUMPS", "FLAT", "FLATS", 
                       "HANDBAG", "HANDBAGS", 
                       "WATCH", "WATCHES",
                       "PANTS", "JEANS", "DRESS",
                       "TOP", "TOPS", "SWEATER", "SWEATERS", "COAT", "COATS"]

SELECTED_CATEGORIES = ['BATH_RUGS', 'RUG', 'AREA_AREA_RUG', 'AREA_RUG', 'BATH_RUG']

# optional config. Make it empty list if not used.
SELECTED_ATTRIBUTES = ['Handbag Style', 'Handbag Size', 'Handbag Occasion', 'Handbag Material']
SELECTED_ATTRIBUTES = []

# CHANGE THIS
SAVE_OUTPUT_AS = "RUGS_VALIDATION_DATA.h5"

# %% [markdown]
# # Configs Validation

# %%
if len(SELECTED_CATEGORIES) == 0:
    print("ERROR: Please limit your SELECTED_CATEGORIES. Otherwise it takes too long. May also run out of memory.")
    for _ in range(10):
        print("STOP")

# %% [markdown]
# # Load IDM raw files

# %%
# !ls *.h5
# Out:
# raw_attribute_data_shrek_cleaned.h5  raw_text_data_shrek.h5
# raw_attribute_data_shrek.h5	     RUGS_IDM_1118_and_0119_DATA.h5
# raw_image_data_denis.h5		     RUGS_IDM_Nov2018_DATA.h5
# raw_image_data_patrick.h5	     RUGS_VALIDATION_DATA.h5

# %%
# load attr file
raw_attr = pd.read_hdf(ATTR_DATA_FILE)
print("count raw_attr", len(raw_attr))
raw_attr.head()

# %%
unique_cats = raw_attr[raw_attr['ATTR_NAME'] == 'Category']['ATTR_VAL']
unique_cats = list(set(unique_cats))
#unique_cats

# %%
[x for x in unique_cats if 'RUG' in x]
# Out:
# ['BATH_RUGS', 'RUG', 'AREA_AREA_RUG', 'AREA_RUG', 'BATH_RUG']

# %%
# convert Top's -> TOPS 
# basically remove all single quotes and brackets so df_query will work without issues later
# 
# this step takes a long time. So I have saved its output as raw_attribute_data_shrek_cleaned.h5
def clean_category_value(row):
    name = row['ATTR_NAME']
    val = row['ATTR_VAL']
    if name == 'Category':
        val = val.upper()
        val = val.replace(" ", "_")
        val = val.replace("'", "")
    return val 

#raw_attr['ATTR_VAL'] = raw_attr.apply(clean_category_value, axis=1)
#raw_attr.head()

# %%
# apparently there are no duplicates ? strange. I guess if I subsetted by image id there would be
#print(raw_attr.shape, raw_attr.drop_duplicates(keep='first').shape)

# %%
# load image file
raw_image = pd.read_hdf(IMAGE_DATA_FILE)
raw_image = raw_image[raw_image['COLORWAY_IMAGE_ROLE_TYPE'] == 'CPRI']
raw_image = raw_image[['PRODUCT_ID', 'IMAGE_ID']]

print("count raw_image", len(raw_image))

def make_image_filename(row):
    pid = str(row['PRODUCT_ID'])
    return pid[0] + '/' + pid[1] + '/' + pid + '_' + str(row['IMAGE_ID']) + '.jpg'

raw_image['IMAGE_FILE'] = raw_image.apply(make_image_filename, axis=1)

raw_image.head()
# Out:
# count raw_image 705487
#     PRODUCT_ID  IMAGE_ID                IMAGE_FILE
# 0      5923807   9359780   5/9/5923807_9359780.jpg
# 7      5303346   9014538   5/3/5303346_9014538.jpg
# 8      7118640  10436245  7/1/7118640_10436245.jpg
# 9      8220620  10436245  8/2/8220620_10436245.jpg
# 10     5303354   9014637   5/3/5303354_9014637.jpg

# %% [markdown]
# # Filter Attributes df for Selected Categories

# %%
# shoes_query_string = 'ATTR_NAME == "Category" and (ATTR_VAL == "SHOE" or ATTR_VAL == "SHOES")'
# print("\n", "query_string:", shoes_query_string)
# shoes_cat_df = raw_attr.query(shoes_query_string)
# shoes_cat_pids = list(set(shoes_cat_df['PROD_ID']))
# shoes_cat_df = raw_attr.loc[raw_attr['PROD_ID'].isin(shoes_cat_pids)]
# print("\n", "count shoes_cat_pids", len(shoes_cat_pids))

# boots_query_string = 'PROD_ID == @shoes_cat_pids and ATTR_NAME == "Shoe Type" and (ATTR_VAL == "Pump" or ATTR_VAL == "Pumps")'
# print("\n", "query_string:", boots_query_string)
# cat_df = raw_attr.query(boots_query_string)
# cat_pids = list(set(cat_df['PROD_ID']))
# cat_df = raw_attr.loc[raw_attr['PROD_ID'].isin(cat_pids)]
# print("\n", "count cat_pids", len(cat_pids))

rugs_query_string = 'PROD_ID == @rugs_cat_pids and ATTR_NAME == "Shoe Type" and (ATTR_VAL == "Pump" or ATTR_VAL == "Pumps")'
rugs_query_string = 'PROD_ID == @rugs_cat_pids and ATTR_NAME == "Shoe Type" and (ATTR_VAL == "Pump" or ATTR_VAL == "Pumps")'
rugs_query_string = 'PROD_ID == @rugs_cat_pids and ATTR_NAME == "Shoe Type" and (ATTR_VAL == "Pump" or ATTR_VAL == "Pumps")'

print("\n", "query_string:", RUGS_query_string)
cat_df = raw_attr.query(boots_query_string)
cat_pids = list(set(cat_df['PROD_ID']))
cat_df = raw_attr.loc[raw_attr['PROD_ID'].isin(cat_pids)]
print("\n", "count cat_pids", len(cat_pids))

print("\n", "df shape:", cat_df.shape)

cat_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-c551d077219a> in <module>()
#      14
#      15 rugs_query_string = 'PROD_ID == @shoes_cat_pids and ATTR_NAME == "Shoe Type" and (ATTR_VAL == "Pump" or ATTR_VAL == "Pumps")'
# ---> 16 print("\n", "query_string:", boots_query_string)
#      17 cat_df = raw_attr.query(boots_query_string)
#      18 cat_pids = list(set(cat_df['PROD_ID']))
#
# NameError: name 'boots_query_string' is not defined

# %%
# if no categories are provided then use all unique categories from the data
if len(SELECTED_CATEGORIES) == 0:
    UNIQUE_CATEGORIES = list(set(raw_attr[raw_attr['ATTR_NAME'] == 'Category']['ATTR_VAL']))
    SELECTED_CATEGORIES = UNIQUE_CATEGORIES
    
# collect unique attributes for selected categories
if len(SELECTED_CATEGORIES) == 1:
    query_string = 'ATTR_NAME == "Category" and ATTR_VAL == "{}"'.format(str(SELECTED_CATEGORIES[0]))
else:
    query_string = 'ATTR_NAME == "Category" and (ATTR_VAL == "{}"'.format(str(SELECTED_CATEGORIES[0]))
    for idx, SELECTED_CATEGORY in enumerate(SELECTED_CATEGORIES):
        if idx == 0: continue
        query_string = query_string + ' or ATTR_VAL == "{}"'.format(str(SELECTED_CATEGORY))
    query_string = query_string + ")"

print("\n", "query_string:", query_string)

cat_df = raw_attr.query(query_string)
cat_pids = list(set(cat_df['PROD_ID']))
cat_df = raw_attr.loc[raw_attr['PROD_ID'].isin(cat_pids)] 
print("\n", "df shape:", cat_df.shape)

cat_df.head()
# Out:
#  query_string: ATTR_NAME == "Category" and (ATTR_VAL == "BATH_RUGS" or ATTR_VAL == "RUG" or ATTR_VAL == "AREA_AREA_RUG" or ATTR_VAL == "AREA_RUG" or ATTR_VAL == "BATH_RUG")
#
#  df shape: (529262, 3)
#        PROD_ID             ATTR_NAME      ATTR_VAL
# 21670    32016         Bath Category     Bath Rugs
# 21671    32016                 Brand  Calvin Klein
# 21672    32016              Category      BATH_RUG
# 21673    32016  Category of Business    Bed & Bath
# 21674    32016  Category of Business          Home

# %%
raw_attr[raw_attr['PROD_ID'] == 32016]
# Out:
#        PROD_ID             ATTR_NAME      ATTR_VAL
# 21670    32016         Bath Category     Bath Rugs
# 21671    32016                 Brand  Calvin Klein
# 21672    32016              Category      BATH_RUG
# 21673    32016  Category of Business    Bed & Bath
# 21674    32016  Category of Business          Home
# 21675    32016       Home Categories          Bath
# 21676    32016                 Style       Classic
# 21677    32016                 Style        Modern
# 21678    32016                 Style   Traditional

# %%
image_pids = list(set(raw_image['PRODUCT_ID']))

print("cat_pids", len(cat_pids))
print("image_pids", len(image_pids))


inter = list(set(cat_pids) & set(image_pids))
print("inter", len(inter))
# Out:
# cat_pids 49502
# image_pids 417001
# inter 16078

# %% [markdown]
# # Pivot cat_df

# %%
def dedup_rows(x):
    if len(x) > 1:
        o = set([i for i in x])
        return ', '.join(o)
    else:
        return x
    
aggregations = {
    'ATTR_VAL': dedup_rows
}
cat_df_pivoted = cat_df.groupby(['PROD_ID', 'ATTR_NAME']).agg(aggregations).reset_index()
cat_df_pivoted = cat_df_pivoted.pivot(index='PROD_ID', columns='ATTR_NAME', values='ATTR_VAL')
print("\n", "shape cat_df_pivoted", cat_df_pivoted.shape)
cat_df_pivoted.head()
# Out:
#  shape cat_df_pivoted (49502, 87)
# ATTR_NAME Active Apparel Type Age Group Area Rugs Bath Accessory Style  \
# PROD_ID
# 32016                     NaN       NaN       NaN                  NaN
# 32017                     NaN       NaN       NaN                  NaN
# 65749                     NaN     Adult       NaN                  NaN
# 92375                     NaN       NaN       NaN                  NaN
# 92530                     NaN       NaN       NaN                  NaN
#
# ATTR_NAME Bath Category Bath Type Bed & Bath Type Bed Size  \
# PROD_ID
# 32016         Bath Rugs       NaN             NaN      NaN
# 32017         Bath Rugs       NaN             NaN      NaN
# 65749         Bath Rugs       NaN            Bath      NaN
# 92375               NaN       NaN             NaN      NaN
# 92530         Bath Rugs       NaN            Bath      NaN
#
# ATTR_NAME                                Bedding Color Bedding Features  \
# PROD_ID
# 32016                                              NaN              NaN
# 32017                                              NaN              NaN
# 65749      Green, Purple, Brown/Tan, White/Ivory, Grey              NaN
# 92375                                              NaN              NaN
# 92530                                              NaN              NaN
#
# ATTR_NAME     ...     Table Linen Type Textiles Bed Size Top Style  \
# PROD_ID       ...
# 32016         ...                  NaN               NaN       NaN
# 32017         ...                  NaN               NaN       NaN
# 65749         ...                  NaN               NaN       NaN
# 92375         ...                  NaN               NaN       NaN
# 92530         ...                  NaN               NaN       NaN
#
# ATTR_NAME Towel Fabric Towel Size Towel Style Underwear Style Weather  \
# PROD_ID
# 32016              NaN        NaN         NaN             NaN     NaN
# 32017              NaN        NaN         NaN             NaN     NaN
# 65749              NaN        NaN         NaN             NaN     NaN
# 92375              NaN        NaN         NaN             NaN     NaN
# 92530              NaN        NaN         NaN             NaN     NaN
#
# ATTR_NAME Wedding Registry Window Type
# PROD_ID
# 32016                  NaN         NaN
# 32017                  NaN         NaN
# 65749                  NaN         NaN
# 92375                  NaN         NaN
# 92530                  NaN         NaN
#
# [5 rows x 87 columns]

# %% [markdown]
# # Merge ImageData with AttributeData

# %%
merged_df = raw_image.merge(cat_df_pivoted, left_on="PRODUCT_ID", right_on="PROD_ID")
print("\n", "shape merged_df", merged_df.shape)
merged_df.tail()
# Out:
#  shape merged_df (22949, 90)
#        PRODUCT_ID  IMAGE_ID                IMAGE_FILE Active Apparel Type  \
# 22944     7797235  11181971  7/7/7797235_11181971.jpg                 NaN
# 22945     8081323  11508662  8/0/8081323_11508662.jpg                 NaN
# 22946     7689754  11090774  7/6/7689754_11090774.jpg                 NaN
# 22947     8006588  11396879  8/0/8006588_11396879.jpg                 NaN
# 22948     8006584  11396879  8/0/8006584_11396879.jpg                 NaN
#
#       Age Group Area Rugs Bath Accessory Style Bath Category Bath Type  \
# 22944       NaN      true                  NaN           NaN       NaN
# 22945       NaN      true                  NaN           NaN       NaN
# 22946       NaN      true                  NaN           NaN       NaN
# 22947       NaN      true                  NaN           NaN       NaN
# 22948       NaN      true                  NaN           NaN       NaN
#
#       Bed & Bath Type     ...     Table Linen Type Textiles Bed Size  \
# 22944             NaN     ...                  NaN               NaN
# 22945             NaN     ...                  NaN               NaN
# 22946             NaN     ...                  NaN               NaN
# 22947             NaN     ...                  NaN               NaN
# 22948             NaN     ...                  NaN               NaN
#
#       Top Style Towel Fabric Towel Size Towel Style Underwear Style Weather  \
# 22944       NaN          NaN        NaN         NaN             NaN     NaN
# 22945       NaN          NaN        NaN         NaN             NaN     NaN
# 22946       NaN          NaN        NaN         NaN             NaN     NaN
# 22947       NaN          NaN        NaN         NaN             NaN     NaN
# 22948       NaN          NaN        NaN         NaN             NaN     NaN
#
#       Wedding Registry Window Type
# 22944              NaN         NaN
# 22945              NaN         NaN
# 22946              NaN         NaN
# 22947              NaN         NaN
# 22948              NaN         NaN
#
# [5 rows x 90 columns]

# %%
merged_df.columns
# Out:
# Index(['PRODUCT_ID', 'IMAGE_ID', 'IMAGE_FILE', 'Active Apparel Type',
#        'Age Group', 'Area Rugs', 'Bath Accessory Style', 'Bath Category',
#        'Bath Type', 'Bed & Bath Type', 'Bed Size', 'Bedding Color',
#        'Bedding Features', 'Brand', 'Bridal', 'Case Shape', 'Category',
#        'Category of Business', 'Certifications', 'Characters',
#        'Characters - EA', 'Collection', 'College Team', 'Color Family',
#        'Cookware Material', 'Department Type', 'Dress Occasion', 'Fabric',
#        'Fabric Pattern', 'Fabric Property', 'Fill', 'Foam',
#        'Furniture Category', 'Gender', 'Gender/Age', 'Gold Metal Weight',
#        'Hat Style', 'Holiday', 'Holiday Decor Type', 'Home Categories',
#        'Home Organization', 'Kids Bath', 'Kitchen Linen Type', 'Kitchen Type',
#        'Laundry Organization Type', 'League', 'Lids Clothing & Accessories',
#        'Lids For The Home', 'Makeup Category', 'Material', 'Memory Foam',
#        'Memory Foam Rugs', 'Mens Product Type', 'Mom Style',
#        'More Colors Available', 'Multipacks', 'NRF_ID', 'Occasion',
#        'Ornament Style', 'Outdoor Accessories', 'Overlay Bottom',
#        'Product Color', 'Product Level', 'Professional Team', 'Room Type',
#        'Rug Color', 'Rug Construction', 'Rug Size', 'Rug Style', 'Rug Type',
#        'Rugs Pattern', 'Shoe Collection', 'Shoe Style', 'Shoe Type',
#        'Shower Curtain Accessory Type', 'Sleeve Length', 'Special Size',
#        'Stone Setting', 'Style', 'Sub Brand', 'Table Linen Type',
#        'Textiles Bed Size', 'Top Style', 'Towel Fabric', 'Towel Size',
#        'Towel Style', 'Underwear Style', 'Weather', 'Wedding Registry',
#        'Window Type'],
#       dtype='object')

# %% [markdown]
# # Visualize final df

# %%
columns_names = [
    'PRODUCT_ID', 'IMAGE_ID','IMAGE_FILE', 'Area Rugs', 'Bath Accessory Style', 'Bath Category', 'Bath Type',
    'Bed & Bath Type', 'Brand', 'Category', 'Category of Business', 'Collection', 'Color Family', 'Department Type', 
    'Fabric', 'Fabric Pattern', 'Fabric Property', 'Fill', 'Furniture Category', 'Home Categories',
    'Home Organization', 'Kitchen Type', 'Material', 'Memory Foam', 'Memory Foam Rugs', 
    'NRF_ID', 'Outdoor Accessories', 'Product Color', 'Product Level', 'Room Type', 'Rug Color', 'Rug Construction', 
    'Rug Size', 'Rug Style', 'Rug Type', 'Rugs Pattern', 'Style', 'Sub Brand']

#columns_names = ['IMAGE_FILE', 'Category', 'Shoe Type']
print(SELECTED_ATTRIBUTES)
columns_names.extend(SELECTED_ATTRIBUTES)
print(columns_names)
viz_df = merged_df[columns_names].dropna(how='all',axis=1)
print("\n", "shape viz_df", viz_df.shape)
print("\n", viz_df['Rug Type'].unique())
viz_df.head()
# Out:
# []
# ['PRODUCT_ID', 'IMAGE_ID', 'IMAGE_FILE', 'Area Rugs', 'Bath Accessory Style', 'Bath Category', 'Bath Type', 'Bed & Bath Type', 'Brand', 'Category', 'Category of Business', 'Collection', 'Color Family', 'Department Type', 'Fabric', 'Fabric Pattern', 'Fabric Property', 'Fill', 'Furniture Category', 'Home Categories', 'Home Organization', 'Kitchen Type', 'Material', 'Memory Foam', 'Memory Foam Rugs', 'NRF_ID', 'Outdoor Accessories', 'Product Color', 'Product Level', 'Room Type', 'Rug Color', 'Rug Construction', 'Rug Size', 'Rug Style', 'Rug Type', 'Rugs Pattern', 'Style', 'Sub Brand']
#
#  shape viz_df (22949, 31)
#
#  [nan 'Medium' 'Large' 'Small' 'Bath' 'Bath, Contour' 'Small, Contour'
#  'Medium, Contour' 'Medium, Small' 'Medium, Holiday' 'Holiday']
#    PRODUCT_ID  IMAGE_ID                IMAGE_FILE Area Rugs  \
# 0     7797410  11181817  7/7/7797410_11181817.jpg      true
# 1     7797410  11181813  7/7/7797410_11181813.jpg      true
# 2     7797411  11181817  7/7/7797411_11181817.jpg      true
# 3     7797411  11181813  7/7/7797411_11181813.jpg      true
# 4     7797409  11181817  7/7/7797409_11181817.jpg      true
#
#   Bath Accessory Style Bath Category Bath Type Bed & Bath Type       Brand  \
# 0                  NaN           NaN       NaN             NaN  Bob Mackie
# 1                  NaN           NaN       NaN             NaN  Bob Mackie
# 2                  NaN           NaN       NaN             NaN  Bob Mackie
# 3                  NaN           NaN       NaN             NaN  Bob Mackie
# 4                  NaN           NaN       NaN             NaN  Bob Mackie
#
#    Category    ...    Outdoor Accessories Product Color Rug Color  \
# 0  AREA_RUG    ...                    NaN           NaN      Blue
# 1  AREA_RUG    ...                    NaN           NaN      Blue
# 2  AREA_RUG    ...                    NaN           NaN      Blue
# 3  AREA_RUG    ...                    NaN           NaN      Blue
# 4  AREA_RUG    ...                    NaN           NaN      Blue
#
#   Rug Construction Rug Size Rug Style Rug Type Rugs Pattern        Style  \
# 0              NaN      5x8    Indoor      NaN     Oriental  Traditional
# 1              NaN      5x8    Indoor      NaN     Oriental  Traditional
# 2              NaN     8x10    Indoor      NaN     Oriental  Traditional
# 3              NaN     8x10    Indoor      NaN     Oriental  Traditional
# 4              NaN      3x5    Indoor      NaN     Oriental  Traditional
#
#   Sub Brand
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 31 columns]

# %%
viz_df = viz_df.drop_duplicates(subset=['IMAGE_FILE'],keep='first')

# %%
viz_df['Rug Type'].value_counts()
# Out:
# Medium             739
# Small              342
# Bath               234
# Large              173
# Medium, Contour     22
# Bath, Contour       12
# Small, Contour       8
# Medium, Small        6
# Holiday              3
# Medium, Holiday      1
# Name: Rug Type, dtype: int64

# %%
viz_df['Rug Type'].unique()
# Out:
# array([nan, 'Medium', 'Large', 'Small', 'Bath', 'Bath, Contour',
#        'Small, Contour', 'Medium, Contour', 'Medium, Small',
#        'Medium, Holiday', 'Holiday'], dtype=object)

# %% [markdown]
# # Save df

# %%
#merged_df.to_hdf(SAVE_OUTPUT_AS, key="macys_images")
viz_df.to_hdf(SAVE_OUTPUT_AS, key="macys_rug_images")
print("Saved")
# Out:
# Saved
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:1996: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['IMAGE_FILE', 'Area Rugs', 'Bath Accessory Style', 'Bath Category', 'Bath Type', 'Bed & Bath Type', 'Brand', 'Category', 'Category of Business', 'Color Family', 'Fabric', 'Fabric Pattern', 'Fabric Property', 'Fill', 'Furniture Category', 'Home Categories', 'Kitchen Type', 'Material', 'NRF_ID', 'Outdoor Accessories', 'Product Color', 'Rug Color', 'Rug Construction', 'Rug Size', 'Rug Style', 'Rug Type', 'Rugs Pattern', 'Style', 'Sub Brand']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %% [markdown]
# # Reload for QA

# %%
reloaded_df = pd.read_hdf(SAVE_OUTPUT_AS,key="macys_rug_images")
print("\n", "shape reloaded", reloaded_df.shape)
reloaded_df.head()
# Out:
#  shape reloaded (22857, 31)
#    PRODUCT_ID  IMAGE_ID                IMAGE_FILE Area Rugs  \
# 0     7797410  11181817  7/7/7797410_11181817.jpg      true
# 1     7797410  11181813  7/7/7797410_11181813.jpg      true
# 2     7797411  11181817  7/7/7797411_11181817.jpg      true
# 3     7797411  11181813  7/7/7797411_11181813.jpg      true
# 4     7797409  11181817  7/7/7797409_11181817.jpg      true
#
#   Bath Accessory Style Bath Category Bath Type Bed & Bath Type       Brand  \
# 0                  NaN           NaN       NaN             NaN  Bob Mackie
# 1                  NaN           NaN       NaN             NaN  Bob Mackie
# 2                  NaN           NaN       NaN             NaN  Bob Mackie
# 3                  NaN           NaN       NaN             NaN  Bob Mackie
# 4                  NaN           NaN       NaN             NaN  Bob Mackie
#
#    Category    ...    Outdoor Accessories Product Color Rug Color  \
# 0  AREA_RUG    ...                    NaN           NaN      Blue
# 1  AREA_RUG    ...                    NaN           NaN      Blue
# 2  AREA_RUG    ...                    NaN           NaN      Blue
# 3  AREA_RUG    ...                    NaN           NaN      Blue
# 4  AREA_RUG    ...                    NaN           NaN      Blue
#
#   Rug Construction Rug Size Rug Style Rug Type Rugs Pattern        Style  \
# 0              NaN      5x8    Indoor      NaN     Oriental  Traditional
# 1              NaN      5x8    Indoor      NaN     Oriental  Traditional
# 2              NaN     8x10    Indoor      NaN     Oriental  Traditional
# 3              NaN     8x10    Indoor      NaN     Oriental  Traditional
# 4              NaN      3x5    Indoor      NaN     Oriental  Traditional
#
#   Sub Brand
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 31 columns]

# %%
reloaded_df['Category'].unique()
# Out:
# array(['AREA_RUG', 'BATH_RUG', 'RUG'], dtype=object)

# %%
prod_types = ['AREA_RUG', 'BATH_RUG', 'RUG']
for cat in SELECTED_CATEGORIES:
    tmp_df = reloaded_df[reloaded_df['Category'].isin(prod_types)]
    print(cat, len(tmp_df))
# Out:
# BATH_RUGS 22857
# RUG 22857
# AREA_AREA_RUG 22857
# AREA_RUG 22857
# BATH_RUG 22857

# %%
for attr in viz_df.columns[3:]:
    print(attr)
    print(viz_df[attr].value_counts())
# Out:
# Area Rugs
# true    20192
# Name: Area Rugs, dtype: int64
# Bath Accessory Style
# Bathroom Sets    7
# Name: Bath Accessory Style, dtype: int64
# Bath Category
# Bath Rugs                          2088
# Bath Rugs, Towels                    75
# Bath Rugs, Bathroom Accessories      18
# Bath Rugs, Shower Curtains           10
# Towels                                9
# Bathroom Accessories                  5
# Name: Bath Category, dtype: int64
# Bath Type
# Solid      103
# Kids         6
# Holiday      2
# Fashion      1
# Name: Bath Type, dtype: int64
# Bed & Bath Type
# Bath    2210
# Name: Bed & Bath Type, dtype: int64
# Brand
# Surya                             9174
# Oriental Weavers                  1862
# Macy's Fine Rug Gallery           1167
# Loloi                             1107
# Liora Manne'                       974
# Karastan                           787
# KM Home                            684
# Castle Hill London                 653
# Nourison                           562
# Safavieh                           511
# Kas                                371
# JHB Design                         346
# Dalyn                              324
# Couristan                          301
# Kathy Ireland                      250
# Tommy Bahama Home                  235
# Hotel Collection                   223
# Kenneth Mink                       207
# Orian Rugs                         168
# Libby Langdon                      164
# Perthshire Platinum Collection     160
# Bacova                             147
# Momeni                             136
# D Style                            124
# Bungalow Flooring                  122
# Novogratz Collection               118
# Madison Park                       117
# Justina Blakeney                   116
# Martha Stewart Collection          102
# Charter Club                        97
#                                   ...
# bluebellgray                        15
# John Robshaw                        13
# WellnessMats                        12
# Saturday Knight                     10
# Croscill                            10
# Goodful                             10
# Linum Home                           9
# Tervis Tumbler                       9
# Dena                                 8
# Lamont                               6
# Bath Bliss                           6
# Jay Franco                           5
# Global Goods Partners                5
# French Connection                    5
# Jeanne Pierre                        5
# Chilewich                            4
# Eagles Wings                         3
# Nautica                              3
# Dream Factory                        3
# kate spade new york                  3
# Conair                               3
# Maples                               3
# Winning Streak                       2
# Michael Aram                         2
# Lenox                                2
# Creative Bath                        2
# CHF INDUSTRIES INC                   1
# Betsey Johnson                       1
# Bardwil                              1
# HipStyle                             1
# Name: Brand, Length: 88, dtype: int64
# Category
# AREA_RUG    20608
# BATH_RUG     2199
# RUG            50
# Name: Category, dtype: int64
# Category of Business
# Home                20276
# Home, Bed & Bath     2528
# Men's                  14
# Home, Kitchen          12
# Home, Dining            4
# Furniture, Home         2
# Home, Men's             1
# Name: Category of Business, dtype: int64
# Color Family
# Blue                                                  3280
# Gray                                                  2232
# Tan/Beige                                             2112
# Multi                                                 1043
# Green                                                  767
# Brown                                                  740
# Tan/Beige, White, Blue, Green, Ivory/Cream, Silver     675
# Red                                                    561
# Black                                                  556
# Orange                                                 480
# Pink                                                   380
# White                                                  262
# Blue, Gray                                             261
# Blue, Gray, Tan/Beige                                  237
# Blue, Tan/Beige                                        229
# Ivory/Cream                                            217
# Yellow                                                 203
# Tan/Beige, Blue, Red                                   164
# Gold                                                   152
# Blue, Red                                              144
# Tan/Beige, Gray                                        134
# Purple                                                 124
# Blue, Ivory/Cream                                      108
# Blue, Brown                                            102
# Blue, Orange                                           101
# Gray, White                                             80
# Blue, Gray, Green, Multi                                73
# Blue, Gray, Ivory/Cream                                 72
# Blue, Gray, White                                       69
# Blue, Multi                                             66
#                                                       ...
# Silver, Blue, Tan/Beige, Ivory/Cream                     4
# Purple, Multi, Orange                                    4
# Blue, Yellow, Black                                      4
# Gray, Brown, Multi                                       4
# Blue, Yellow, Pink                                       4
# Tan/Beige, White, Silver                                 4
# Blue, Gray, Green                                        4
# Blue, Brown, Yellow                                      4
# Blue, Tan/Beige, Pink                                    3
# Green, Brown, Black                                      3
# Blue, Gray, Red                                          3
# Tan/Beige, Gray, White                                   3
# Blue, Red, Yellow                                        3
# Brown, Red, Black                                        3
# Blue, Multi, Silver                                      3
# Green, Blue, Brown                                       3
# Blue, Gray, Red, Yellow                                  3
# Blue, Green, Purple                                      3
# Purple, Gray                                             3
# Blue, Gray, Purple                                       3
# Gray, White, Green                                       3
# Gray, Black                                              2
# Brown, Black                                             2
# Yellow, Silver                                           2
# Multi, Black                                             2
# Multi, Pink                                              2
# Red, Blue, Gray, Green, Black, Pink, Brown               2
# Brown, Yellow                                            2
# Blue, Green                                              2
# Tan/Beige, Blue, Multi, Brown, Orange                    1
# Name: Color Family, Length: 295, dtype: int64
# Fabric
# Cotton                                  701
# Polyester                               105
# Skid Resistant                           54
# Synthetic, Cotton                        37
# Synthetic                                32
# Turkish Cotton, Cotton                   30
# Pima Cotton, Cotton                      29
# Synthetic, Polyester, Skid Resistant     21
# Nylon                                    20
# Skid Resistant, Cotton                   19
# Cotton Blend                             13
# Synthetic, Polyester                     10
# Acrylic                                   6
# Faux Fur                                  5
# Turkish Cotton                            4
# Cotton/Polyester, Polyester, Cotton       4
# Chenille                                  4
# Poly Blend                                1
# Name: Fabric, dtype: int64
# Fabric Pattern
# Solid             39
# Stripe            18
# Floral            14
# Bohemian           8
# Holiday            6
# Geometric          3
# Coastal            3
# Animal Print       3
# Floral, Stripe     1
# Name: Fabric Pattern, dtype: int64
# Fabric Property
# Reversible                           72
# Ultra-Soft                           44
# Quick Drying                         41
# Moisture Wicking, Water Resistant     8
# Name: Fabric Property, dtype: int64
# Fill
# Cotton       46
# Polyester     4
# Foam          1
# Name: Fill, dtype: int64
# Furniture Category
# Outdoor Accessories    797
# Name: Furniture Category, dtype: int64
# Home Categories
# Rugs                     20270
# Bath                      2535
# Rugs, Bath                  22
# Kitchen                     12
# Dining & Entertaining        5
# Name: Home Categories, dtype: int64
# Kitchen Type
# Kitchen Gadgets    12
# Name: Kitchen Type, dtype: int64
# Material
# Acrylic                             6
# Aluminum/Cast Aluminum, Aluminum    4
# Name: Material, dtype: int64
# NRF_ID
# 20                                       1157
# 440                                      1028
# 60                                       1007
# 250                                       987
# 0                                         848
# 400                                       762
# 960                                       726
# 200                                       698
# 240                                       538
# 450, 100, 215, 45, 105, 338, 440, 255     533
# 600                                       528
# 401                                       487
# 300                                       485
# 410                                       388
# 800                                       376
# 460                                       293
# 1                                         274
# 280                                       237
# 260                                       196
# 750                                       193
# 961                                       163
# 998                                       155
# 840                                       137
# 690                                       133
# 650                                       130
# 100                                       122
# 110                                       122
# 270                                       122
# 340                                       120
# 30                                        114
#                                          ...
# 654                                         1
# 160                                         1
# 60, 960                                     1
# 329                                         1
# 485                                         1
# 408                                         1
# 215                                         1
# 424                                         1
# 264                                         1
# 31                                          1
# 17                                          1
# 100, 400, 410, 200, 20                      1
# 269                                         1
# 607                                         1
# 39                                          1
# 454                                         1
# 451                                         1
# 180                                         1
# 274                                         1
# 415                                         1
# 214                                         1
# 587                                         1
# 424, 810, 212, 246, 243, 441, 245           1
# 712                                         1
# 930                                         1
# 676                                         1
# 445                                         1
# 660                                         1
# 671                                         1
# 491                                         1
# Name: NRF_ID, Length: 657, dtype: int64
# Outdoor Accessories
# Outdoor Rugs    790
# Name: Outdoor Accessories, dtype: int64
# Product Color
# White, Blue, Gray, Green, Ivory/Cream, Brown                            68
# Tan/Beige, White, Red, Blue, Gray, Green, Purple, Ivory/Cream, Brown    57
# Gray                                                                    28
# Red, Blue, Green, Ivory/Cream, Brown, Yellow, Orange                    11
# Name: Product Color, dtype: int64
# Rug Color
# Multi                                            11412
# Blue                                              1487
# Gray                                              1227
# Ivory/Cream                                        768
# Brown                                              606
# Tan/Beige                                          517
# Green                                              438
# Red                                                334
# Black                                              222
# Orange                                             177
# Blue, Ivory/Cream                                  167
# Blue, Gray                                         141
# Blue, Multi                                        127
# Tan/Beige, Multi                                   108
# Gray, Ivory/Cream                                  107
# Gold                                                85
# Tan/Beige, Ivory/Cream                              71
# Purple                                              69
# Blue, Green                                         58
# Blue, Tan/Beige                                     58
# Red, Ivory/Cream                                    58
# Multi, Ivory/Cream                                  57
# Gray, Gold                                          56
# Yellow                                              46
# Multi, Black                                        46
# Multi, Brown                                        45
# Gray, Multi                                         45
# Gray, Black                                         43
# Pink                                                42
# Brown, Ivory/Cream                                  40
#                                                  ...
# Blue, White                                          2
# Multi, Red, Black                                    2
# Blue, Gold, Black                                    2
# Gray, Yellow                                         2
# Purple, Orange                                       2
# Green, Red, Gold, Ivory/Cream                        2
# Purple, Gray                                         2
# Brown, Orange                                        2
# Silver, Ivory/Cream                                  2
# Purple, Tan/Beige                                    2
# Purple, Multi, Green                                 1
# Tan/Beige, Multi, Red                                1
# Silver, Tan/Beige, Gray, Ivory/Cream                 1
# Multi, Brown, Ivory/Cream                            1
# Gray, Red                                            1
# Purple, Gray, Multi                                  1
# Tan/Beige, Green                                     1
# Blue, Multi, Green                                   1
# Blue, Multi, Brown                                   1
# Tan/Beige, White, Ivory/Cream                        1
# Green, Black                                         1
# White, Brown                                         1
# Blue, Purple, Red, Ivory/Cream                       1
# Purple, Gray, Silver                                 1
# Gray, Brown, Multi                                   1
# Red, Green, Black, Gold, Brown                       1
# Tan/Beige, Gray, Ivory/Cream, Silver, Orange         1
# Silver, Blue, Gray, Pink                             1
# Red, Blue, Purple, Ivory/Cream, Multi, Orange        1
# Multi, Red, Ivory/Cream                              1
# Name: Rug Color, Length: 113, dtype: int64
# Rug Construction
# Tufted                       174
# Shag Rugs                     55
# Tufted, Handmade Rugs         40
# Handmade Rugs                 36
# Flat Woven, Handmade Rugs      8
# Hand Knotted                   3
# Name: Rug Construction, dtype: int64
# Rug Size
# 8x10                          3041
# 5x8                           2847
# Runner                        2169
# 2x3                           1818
# 4x6                           1454
# 9x12                          1284
# Rug Swatch                     995
# 3x5                            917
# Round                          776
# 10x13                          709
# 7x9                            633
# Square                         459
# 6x9                            340
# 12x15                          241
# Rug Sets                        70
# 7x9, 8x10                       59
# 8x10, 9x12                      59
# 10x13, 9x12                     34
# Doormat                         28
# 6x9, 7x9                        24
# 7x9, Round                      14
# Square, Rug Swatch              11
# Round, Runner                    8
# Round, 10x13                     8
# Runner, 5x8                      4
# Round, 10x13, Runner             4
# 10x13, Runner                    4
# 7x9, 3x5                         4
# 8x10, Runner                     3
# Rug Swatch, 5x8                  3
# Runner, Rug Sets, 3x5, 5x8       3
# 12x15, 9x12                      3
# 8x10, Rug Swatch                 3
# Rug Sets, Runner                 2
# Rug Swatch, 2x3                  2
# Doormat, 2x3                     2
# Square, 9x12                     1
# Name: Rug Size, dtype: int64
# Rug Style
# Indoor                       14702
# Bath                          1576
# Outdoor, Indoor               1041
# Kitchen, Indoor               1003
# Shag                           731
# Accent                         297
# Outdoor                        284
# Kids, Shag                      93
# Doormats                        77
# Accent, Bath                    72
# Natural                         72
# Natural, Indoor                 70
# Rug Sets, Indoor                51
# Doormats, Outdoor               33
# Rug Sets                        28
# Accent, Kitchen                 19
# Rug Sets, Bath                  18
# Outdoor, Doormats, Indoor       13
# Novelty                          6
# Novelty, Indoor                  5
# Kids                             5
# Shag, Indoor                     2
# Kitchen                          2
# Accent, Doormats                 1
# Accent, Doormats, Outdoor        1
# Name: Rug Style, dtype: int64
# Rug Type
# Medium             739
# Small              342
# Bath               234
# Large              173
# Medium, Contour     22
# Bath, Contour       12
# Small, Contour       8
# Medium, Small        6
# Holiday              3
# Medium, Holiday      1
# Name: Rug Type, dtype: int64
# Rugs Pattern
# Oriental                                6081
# Geometric                               3932
# Solid                                   2786
# Abstract                                2550
# Patterned                               1519
# Floral                                  1410
# Striped                                  849
# Bordered                                 300
# Global Inspired                          274
# Striped, Solid                           229
# Chevron                                  138
# Coastal                                  119
# Patterned, Solid                          94
# Damask                                    48
# Animal Print                              41
# Geometric, Patterned                      40
# Bordered, Solid                           30
# Oriental, Global Inspired                 29
# Holiday                                   21
# Patterned, Damask                         20
# Abstract, Patterned                       20
# Striped, Patterned                        17
# Floral, Oriental                          14
# Abstract, Geometric                       11
# Floral, Patterned                         10
# Global Inspired, Patterned                 8
# Oriental, Abstract                         7
# Abstract, Solid                            6
# Global Inspired, Abstract                  4
# Floral, Bordered                           4
# Abstract, Bordered                         4
# Holiday, Solid                             3
# Holiday, Patterned                         2
# Oriental, Global Inspired, Patterned       2
# Bordered, Damask                           2
# Oriental, Patterned                        2
# Name: Rugs Pattern, dtype: int64
# Style
# Modern                                                  8023
# Traditional                                             4549
# Freestyle                                               4214
# Casual, Modern, Transitional                             382
# Traditional, Modern                                      284
# Transitional                                             226
# Casual                                                   171
# Casual, Modern                                           171
# Modern, Freestyle                                        160
# Modern, Transitional                                     120
# Transitional, Freestyle, Modern, Casual, Traditional     119
# Casual, Traditional, Modern                               91
# Transitional, Freestyle                                   76
# Traditional, Modern, Freestyle                            70
# Casual, Modern, Transitional, Freestyle                   61
# Modern, Transitional, Freestyle                           53
# Casual, Transitional, Freestyle                           30
# Traditional, Transitional                                 21
# Traditional, Modern, Transitional                          2
# Traditional, Freestyle                                     1
# Farmhouse                                                  1
# Name: Style, dtype: int64
# Sub Brand
# Lauren Ralph Lauren                  36
# Madison Park Essentials              27
# Monte Carlo                           6
# Martha Stewart Essentials             4
# Whim by Martha Stewart Collection     1
# Name: Sub Brand, dtype: int64

# %%
final_rug_cols = [
    'PRODUCT_ID', 'IMAGE_ID', 'IMAGE_FILE', 'Brand', 'Category', 'Color Family', 'Fabric', 
    'Fabric Pattern', 'Fabric Property', 'Material','Product Color', 'Rug Color', 'Rug Construction', 
    'Rug Size', 'Rug Style', 'Rug Type', 'Rugs Pattern', 'Style', 'Sub Brand']
filtered_rug_df = viz_df[final_rug_cols]

# %%
print(filtered_rug_df.dropna(subset=['Rug Style']).shape)
filtered_rug_df['Rug Style'].value_counts()
# Out:
# (20202, 19)
# Indoor                       14702
# Bath                          1576
# Outdoor, Indoor               1041
# Kitchen, Indoor               1003
# Shag                           731
# Accent                         297
# Outdoor                        284
# Kids, Shag                      93
# Doormats                        77
# Accent, Bath                    72
# Natural                         72
# Natural, Indoor                 70
# Rug Sets, Indoor                51
# Doormats, Outdoor               33
# Rug Sets                        28
# Accent, Kitchen                 19
# Rug Sets, Bath                  18
# Outdoor, Doormats, Indoor       13
# Novelty                          6
# Novelty, Indoor                  5
# Kids                             5
# Shag, Indoor                     2
# Kitchen                          2
# Accent, Doormats                 1
# Accent, Doormats, Outdoor        1
# Name: Rug Style, dtype: int64

# %%
print(filtered_rug_df.dropna(subset=['Style']).shape)
filtered_rug_df['Style'].value_counts()
# Out:
# (18825, 19)
# Modern                                                  8023
# Traditional                                             4549
# Freestyle                                               4214
# Casual, Modern, Transitional                             382
# Traditional, Modern                                      284
# Transitional                                             226
# Casual                                                   171
# Casual, Modern                                           171
# Modern, Freestyle                                        160
# Modern, Transitional                                     120
# Transitional, Freestyle, Modern, Casual, Traditional     119
# Casual, Traditional, Modern                               91
# Transitional, Freestyle                                   76
# Traditional, Modern, Freestyle                            70
# Casual, Modern, Transitional, Freestyle                   61
# Modern, Transitional, Freestyle                           53
# Casual, Transitional, Freestyle                           30
# Traditional, Transitional                                 21
# Traditional, Modern, Transitional                          2
# Traditional, Freestyle                                     1
# Farmhouse                                                  1
# Name: Style, dtype: int64
